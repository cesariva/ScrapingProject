# %%
# !pip install BeautifulSoup4
#! pip install --upgrade beautifulsoup4
! pip install --upgrade html5lib
#! pip install --upgrade pip
#! pip install bs4
#Para realizar las consultas HTTP
import requests
#Para realizar el parsing del HTML
from bs4 import BeautifulSoup
#Para interpretar el json
import json
# Out:
# Requirement already satisfied: BeautifulSoup4 in /opt/conda/lib/python3.6/site-packages
# You are using pip version 9.0.1, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already up-to-date: html5lib in /opt/conda/lib/python3.6/site-packages
# Collecting six>=1.9 (from html5lib)
#   Downloading https://files.pythonhosted.org/packages/73/fb/00a976f728d0d1fecfe898238ce23f502a721c0ac0ecfedb80e0d88c64e9/six-1.12.0-py2.py3-none-any.whl
# Collecting webencodings (from html5lib)
#   Downloading https://files.pythonhosted.org/packages/f4/24/2a3e3df732393fed8b3ebf2ec078f05546de641fe1b667ee316ec1dcf3b7/webencodings-0.5.1-py2.py3-none-any.whl
# Installing collected packages: six, webencodings
#   Found existing installation: six 1.11.0
#     Uninstalling six-1.11.0:
#       Successfully uninstalled six-1.11.0
#   Found existing installation: webencodings 0.5
#     Uninstalling webencodings-0.5:
#       Successfully uninstalled webencodings-0.5
# Successfully installed six-1.12.0 webencodings-0.5.1
# You are using pip version 9.0.1, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-e4cdf60bfe37> in <module>()
#       7 import requests
#       8 #Para realizar el parsing del HTML
# ----> 9 from bs4 import BeautifulSoup
#      10 #Para interpretar el json
#      11 import json
#
# /opt/conda/lib/python3.6/site-packages/bs4/__init__.py in <module>()
#      28 import warnings
#      29
# ---> 30 from .builder import builder_registry, ParserRejectedMarkup
#      31 from .dammit import UnicodeDammit
#      32 from .element import (
#
# /opt/conda/lib/python3.6/site-packages/bs4/builder/__init__.py in <module>()
#     312 register_treebuilders_from(_htmlparser)
#     313 try:
# --> 314     from . import _html5lib
#     315     register_treebuilders_from(_html5lib)
#     316 except ImportError:
#
# /opt/conda/lib/python3.6/site-packages/bs4/builder/_html5lib.py in <module>()
#      68
#      69
# ---> 70 class TreeBuilderForHtml5lib(html5lib.treebuilders._base.TreeBuilder):
#      71
#      72     def __init__(self, soup, namespaceHTMLElements):
#
# AttributeError: module 'html5lib.treebuilders' has no attribute '_base'

# %%
#Pagina a consultar
page=requests.get("https://www.elfinanciero.com.mx/economia")
#verifica el codigo de respuesta.
page.status_code
# Out:
# 200

# %%
#  Extraemos el contenido de la página
soup=BeautifulSoup(page.content)
# Imprimimos el contenido 
print (soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="es">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <link href="/resources/images/favicon.png" rel="icon" type="image/png"/>
#   <link crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" integrity="sha384-lKuwvrZot6UHsBSfcMvOkWwlCMgc0TaWr+30HWe3a4ltaBwTZhyTEggF5tJv8tbt" rel="stylesheet"/>
#   <link href="/resources/plugins/uikit/css/uikit.min.css" rel="stylesheet" type="text/css"/>
#   <link href="/resources/plugins/uikit/css/components/slider.min.css" rel="stylesheet" type="text/css"/>
#   <link href="/resources/plugins/uikit/css/components/slideshow.min.css" rel="stylesheet" type="text/css"/>
#   <link href="/resources/plugins/uikit/css/components/dotnav.min.css" rel="stylesheet" type="text/css"/>
#   <link href="/resources/plugins/uikit/css/components/slidenav.min.css" rel="stylesheet" type="text/css"/>
#   <link href="/resources/css/trunks.min.css" rel="stylesheet" type="text/css"/>
#   <link href="/resources/css/style.min.css" rel="stylesheet" type="text/css"/>
#   <link href="/resources/css/tv.min.css " rel="stylesheet" type="text/css"/>
#   <link href="https://fonts.googleapis.com/css?family=Merriweather:300,400,400i,700,700i|Rubik:300,400,500,700" rel="stylesheet" type="text/css"/>
#   <link href="https://cdn-images.mailchimp.com/embedcode/classic-10_7.css" rel="stylesheet" type="text/css"/>
#   <style type="text/css">
#    #mc_embed_signup{background:#fff; clear:left; font:14px Helvetica,Arial,sans-serif; }
#   </style>
#   <link href="/resources/css/mailChimp.css" rel="stylesheet" type="text/css"/>
#   <link href="/resources/videoplayer/vast/css/video-player.css" rel="stylesheet" type="text/css"/>
#   <link href="/resources/plugins/videojs-ima/player-ex.css" rel="stylesheet" type="text/css"/>
#   <link href="/resources/plugins/videojs-contrib-ads/videojs.ads.css" rel="stylesheet" type="text/css"/>
#   <link href="/resources/plugins/videojs-ima/videojs.ima.css" rel="stylesheet" type="text/css"/>
#   <!-- MailChimp-->
#   <script src="https://s3.amazonaws.com/downloads.mailchimp.com/js/mc-validate.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    (function($) {window.fnames = new Array(); window.ftypes = new Array();fnames[0]='EMAIL';ftypes[0]='email';fnames[1]='FNAME';ftypes[1]='text';fnames[2]='LNAME';ftypes[2]='text';}(jQuery));var $mcj = jQuery.noConflict(true);
#   </script>
#   <link href="/resources/css/taboola.css " rel="stylesheet" type="text/css"/>
#   <script src="https://cdn.jsdelivr.net/npm/sweetalert2@8">
#   </script>
#   <script>
#    window.dataLayer = [{"cgSeccion":"Economía","cgSubSeccion":"Portadas","cgSubSubSeccion":"Portada de sección"}]
#   </script>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f)
# })(window,document,'script','dataLayer','GTM-PQSN8R3')
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min.js">
#   </script>
#   <script src="/resources/plugins/videojs-ima/video.min.js">
#   </script>
#   <script src="https://imasdk.googleapis.com/js/sdkloader/ima3.js">
#   </script>
#   <script src="https://googleads.github.io/videojs-ima/node_modules/videojs-contrib-ads/dist/videojs.ads.min.js">
#   </script>
#   <script src="https://googleads.github.io/videojs-ima/dist/videojs.ima.js">
#   </script>
#   <script>
#    function udm_(e) {
#   var autor = self.dataLayer[1].cdAutores;
#   var t = "comScore=",
#     n = document,
#     r = n.cookie,
#     i = "",
#     s = "indexOf",
#     o = "substring",
#     u = "length",
#     a = 2048,
#     f, l = "&ns_",
#     c = "&",
#     h, p, d, v, m = window,
#     g = m.encodeURIComponent || escape;
#   if (r[s](t) + 1)
#     for (d = 0, p = r.split(";"), v = p[u]; d < v; d++) h = p[d][s](t), h + 1 && (i = c + unescape(p[d][o](h + t[u])));
#   e += l + "_t=" + +(new Date) + l + "c=" + (n.characterSet || n.defaultCharset || "") + "&c8=" + g(n.title) + i + "&c7=" + g(n.URL) + "&autor=" + autor + "&c9=" + g(n.referrer), e[u] > a && e[s](c) > 0 && (f = e[o](0, a - 8).lastIndexOf(c), e = (e[o](0, f) + l + "cut=" + g(e[o](f + 1)))[o](0, a)), n.images ? (h = new Image, m.ns_p || (ns_p = h), h.src = e) : n.write("<", "p", "><", 'img src="', e, '" height="1" width="1" alt="*"', "><", "/p", ">")
# };
#   udm_('https://sb.scorecardresearch.com/b?c1=2&c2=10181342&ns_site=elfinanciero&name=economia.portada');
#   </script>
#   <script>
#    var _comscore = _comscore || [];
# _comscore.push({ c1: "2", c2: "10181342" });
# (function() {
#   var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#   s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#   el.parentNode.insertBefore(s, el);
# })();
#   </script>
#   <noscript>
#   </noscript>
#  </head>
#  <body>
#   <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=10181342&amp;cv=2.0&amp;cj=1"/>
#   <script src="/resources/js/EF.js">
#   </script>
#   <!--Vast-->
#   <script src="/resources/js/vast.js">
#   </script>
#   <link href="/manifest.json" rel="manifest"/>
#   <script async="" src="https://cdn.onesignal.com/sdks/OneSignalSDK.js">
#   </script>
#   <script>
#    var OneSignal = window.OneSignal || [];
# OneSignal.push(function() {
# OneSignal.init({
# appId: "43ac3dc6-8a02-44da-81a1-b30deedf655e",
# });
# });
#   </script>
#   <script>
#    var page_counter = 0;
#   </script>
#   <!--script.-->
#   <!--  (function(i) {-->
#   <!--    var ts = document.createElement('script');-->
#   <!--    ts.type = 'text/javascript';-->
#   <!--    ts.async = true;-->
#   <!--    ts.src = ('https:' == document.location.protocol ? 'https://' :-->
#   <!--    'http://') + 'tags.t.tailtarget.com/t3m.js?i=' + i;-->
#   <!--    var s = document.getElementsByTagName('script')[0];-->
#   <!--    s.parentNode.insertBefore(ts, s);-->
#   <!--  })('TT-11608-4/CT-...');-->
#   <!--script.-->
#   <!--  EF.client.loadScript(-->
#   <!--    '//tags.t.tailtarget.com/t3m.js?i=TT-11608-4/CT-...',-->
#   <!--    { async: true },-->
#   <!--    function () {-->
#   <!--      var getTailTargetParam = function(a) {-->
#   <!--        var ttCookieName = "_ttdmp";-->
#   <!--        if (!window._ttprofilescache) {-->
#   <!--          window._ttprofilescache = {};-->
#   <!--          try {-->
#   <!--            var c = document.cookie.match('(^|;)\\s*' + ttCookieName + '\\s*=\\s*([^;]+)');-->
#   <!--            var d = c ? c.pop().split('|') : [];-->
#   <!--            for (var i = 0; i < d.length; i++) {-->
#   <!--              var kv = d[i].split(":");-->
#   <!--              if (kv[1] && kv[1].indexOf(",") > 0) {-->
#   <!--                window._ttprofilescache[kv[0]] = kv[1].split(",");-->
#   <!--              } else {-->
#   <!--                window._ttprofilescache[kv[0]] = kv[1];-->
#   <!--              }-->
#   <!--            }-->
#   <!--          } catch (e) {-->
#   <!--          }-->
#   <!--        }-->
#   <!--        return window._ttprofilescache[a] ? window._ttprofilescache[a] : 'na';-->
#   <!--      };-->
#   <!--      window.EF.ads.kv = {-->
#   <!--        "ttLS": getTailTargetParam('LS'),-->
#   <!--        "ttS": getTailTargetParam('S'),-->
#   <!--        "ttT": getTailTargetParam('T'),-->
#   <!--        "ttC": getTailTargetParam('C'),-->
#   <!--        "ttU": getTailTargetParam('U'),-->
#   <!--        "ttCA": getTailTargetParam('CA'),-->
#   <!--        "ttE": getTailTargetParam('E'),-->
#   <!--        "ttA": getTailTargetParam('A'),-->
#   <!--        "ttG": getTailTargetParam('G')-->
#   <!--      }-->
#   <!--  })-->
#   <title>
#    Economía
#   </title>
#   <script data-schema="WebPage" type="application/ld+json">
#    {"@type":"WebPage","@context":"https://schema.org","@id":"https://elfinanciero.com.mx/economia"}
#   </script>
#   <script data-schema="Organization" type="application/ld+json">
#    {"@type":"Organization","@context":"https://schema.org","name":"El Financiero","url":"https://elfinanciero.com.mx","logo":{"@type":"ImageObject","url":"https://elfinanciero.com.mx/images/logo24.png","width":600,"height":60},"sameAS":["https://www.facebook.com/ElFinancieroMx","https://twitter.com/ElFinanciero_Mx","https://plus.google.com/+elfinanciero","https://www.youtube.com/user/FinancieroMexico"]}
#   </script>
#   <script data-schema="ItemList" type="application/ld+json">
#    {"url":"https://elfinanciero.com.mx/economia","itemListElement":[{"@type":"ListItem","position":1,"item":{"url":"https://elfinanciero.com.mx/economia","itemListElement":[{"url":"https://elfinanciero.com.mx/economia/moodys-alerta-sobre-plan-del-gobierno-de-amlo-para-refinerias-de-pemex","@type":"ListItem","position":0},{"url":"https://elfinanciero.com.mx/economia/y-a-todo-esto-cuanto-va-a-crecer-la-economia-de-mexico-en-2019","@type":"ListItem","position":1},{"url":"https://elfinanciero.com.mx/economia/harvard-le-entra-al-negocio-de-cript
#   </script>
#   <!-- Facebook OpenGraph-->
#   <meta content="El Financiero" property="og:site_name"/>
#   <meta content="https://elfinanciero.com.mx/economia" property="og:url"/>
#   <meta content="article" property="og:type"/>
#   <meta content="Economía" property="og:title"/>
#   <meta content="Encuentra en El Financiero las noticias más importantes de la Economía mexicana y mundial, acompañadas del análisis de los mejores especialistas." property="og:description"/>
#   <meta content="https://elfinanciero.com.mx/uploads/2018/01/30/76330c26de1517352566_standard_desktop_fullhd.jpeg" property="og:image"/>
#   <meta property="og:image:width"/>
#   <meta property="og:image:height"/>
#   <meta content="https://elfinanciero.com.mx/uploads/2018/01/30/76330c26de1517352566_standard_desktop_fullhd.jpeg" property="og:image:url"/>
#   <meta content="1063568587023463" property="fb:app_id"/>
#   <meta content="16250043914" property="fb:pages"/>
#   <!-- Twitter card-->
#   <meta content="@ElFinanciero_Mx" property="twitter:creator"/>
#   <meta content="https://elfinanciero.com.mx/economia" property="twitter:url"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="@ElFinanciero_Mx" property="twitter:site"/>
#   <meta content="Economía" property="twitter:title"/>
#   <meta content="Encuentra en El Financiero las noticias más importantes de la Economía mexicana y mundial, acompañadas del análisis de los mejores especialistas." property="twitter:description"/>
#   <meta content="https://elfinanciero.com.mx/uploads/2018/01/30/76330c26de1517352566_standard_desktop_fullhd.jpeg" property="twitter:image:src"/>
#   <meta property="twitter:image:width"/>
#   <meta property="twitter:image:height"/>
#   <!-- SEO-->
#   <meta content="Encuentra en El Financiero las noticias más importantes de la Economía mexicana y mundial, acompañadas del análisis de los mejores especialistas." name="description"/>
#   <meta content="https://elfinanciero.com.mx/uploads/2018/01/30/76330c26de1517352566_standard_desktop_fullhd.jpeg" name="thumbnail"/>
#   <!-- Google Tag Manager (noscript)-->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PQSN8R3" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript)-->
#   <script>
#    // <![CDATA[
# function udm_(e){var t="comScore=",n=document,r=n.cookie,i="",s="indexOf",o="substring",u="length",a=2048,f,l="&ns_",c="&",h,p,d,v,m=window,g=m.encodeURIComponent||escape;if(r[s](t)+1)for(d=0,p=r.split(";"),v=p[u];d<v;d++)h=p[d][s](t),h+1&&(i=c+unescape(p[d][o](h+t[u])));e+=l+"_t="+ +(new Date)+l+"c="+(n.characterSet||n.defaultCharset||"")+"&c8="+g(n.title)+i+"&c7="+g(n.URL)+"&c9="+g(n.referrer),e[u]>a&&e[s](c)>0&&(f=e[o](0,a-8).lastIndexOf(c),e=(e[o](0,f)+l+"cut="+g(e[o](f+1)))[o](0,a)),n.images?(h=new Image,m.ns_p||(ns_p=h),h.src=e):n.write("<","p","><",'img src="',e,'" height="1" width="1" alt="*"',"><","/p",">")};
# //- udm_('http'+(document.location.href.charAt(4)=='s'?'s://sb':'://b')+'.scorecardresearch.com/b?c1=2&c2=10181342&ns_site=su-sitio&name=directory.page');
# // ]]>
#   </script>
#   <div class="ad-slot" data-adtype="home.oop" id="home_oop">
#   </div>
#   <!-- if self.page//- Nota
# +ad('nota', 'top')-->
#   <!--else if !self.isAgro && !self.isOil-->
#   <div class="top-ad-space">
#    <div class="container">
#     <div class="ad-holder">
#      <div class="is-super-banner">
#       <div class="ad-slot top-banner is-hidden-touch" data-adtype="home.top" id="home_top">
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="top-header-wrapper">
#    <div class="top-header" id="top-header">
#     <div class="top-search">
#      <div class="container">
#       <div class="columns is-multiline">
#        <div class="column is-12 has-text-right">
#         <a class="close-search">
#          <i class="fas fa-times">
#          </i>
#         </a>
#        </div>
#        <div class="column is-12">
#         <input class="search-field" placeholder="Buscar" type="text"/>
#        </div>
#        <div class="column is-12 is-hidden-touch help">
#         ESCRIBE LA BÚSQUEDA Y PRESIONA ENTER
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="date is-hidden-touch">
#      <script>
#       var meses = new Array("Enero", "Febrero", "Marzo", "Abril", "Mayo", "Junio", "Julio", "Agosto", "Septiembre", "Octubre", "Noviembre", "Diciembre");
# var f = new Date();
# var mes = meses[f.getMonth()];
# var dd = f.getDate();
# if (dd < 10) {
#   dd = '0' + dd
# }
# document.write(dd + " / " + mes.toUpperCase() + " / " + f.getFullYear());
#      </script>
#     </div>
#     <div class="social is-hidden-touch">
#      <a href="https://www.facebook.com/ElFinancieroMx" target="_blank">
#       <i class="fab fa-facebook-square">
#       </i>
#      </a>
#      <a href="https://twitter.com/ElFinanciero_Mx" target="_blank">
#       <i class="fab fa-twitter">
#       </i>
#      </a>
#      <a href="https://www.linkedin.com/company/90169/" target="_blank">
#       <i class="fab fa-linkedin-in">
#       </i>
#      </a>
#      <a href="https://www.instagram.com/elfinanciero_mx/" target="_blank">
#       <i class="fab fa-instagram">
#       </i>
#      </a>
#     </div>
#     <div class="search-button">
#      <a>
#       <i class="fas fa-search">
#       </i>
#      </a>
#     </div>
#     <div class="touch-menu-trigger is-hidden-desktop">
#      <a id="touch-menu-trigger">
#       <img src="/resources/images/touch-menu-trigger.svg"/>
#      </a>
#     </div>
#     <div class="logo">
#      <a href="/">
#       <picture>
#        <source media="(max-width: 767px)" srcset="/resources/images/img_menu/svg/logo_mobile.svg"/>
#        <source media="(min-width: 768px)" srcset="/resources/images/img_menu/svg/logo.svg"/>
#        <img src="/resources/images/img_menu/png/logo.png"/>
#       </picture>
#      </a>
#      <div class="main-menu is-hidden-touch">
#       <ul>
#        <li class="is-hidden-desktop-medium">
#         <a href="/economia">
#          ECONOMÍA
#         </a>
#        </li>
#        <li>
#         <a href="/mercados">
#          MERCADOS
#         </a>
#        </li>
#        <li>
#         <a href="/opinion">
#          OPINIÓN
#         </a>
#        </li>
#        <li>
#         <a href="/nacional">
#          NACIONAL
#         </a>
#        </li>
#        <li>
#         <a href="/tv">
#          TV
#         </a>
#        </li>
#        <li id="full-menu-trigger">
#         <a>
#          · · ·
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="full-menu" id="full-menu">
#      <div class="back">
#      </div>
#      <div class="container">
#       <div class="columns is-multiline is-menu-row">
#        <div class="column is-3-desktop is-6-tablet is-12-mobile">
#         <ul class="primary is-hidden-tablet">
#          <!--li-->
#          <!--  a(href='/transicion') Transición-->
#          <li>
#           <a href="/economia">
#            Economía
#           </a>
#          </li>
#          <li>
#           <a href="/empresas">
#            Empresas
#           </a>
#          </li>
#          <li>
#           <a href="/mercados">
#            Mercados
#           </a>
#          </li>
#          <li>
#           <a href="/nacional">
#            Nacional
#           </a>
#          </li>
#          <li>
#           <a href="/opinion">
#            Opinión
#           </a>
#          </li>
#          <li>
#           <a href="/tv">
#            Televisión
#           </a>
#          </li>
#          <li>
#           <a href="/bloomberg-businessweek">
#            Bloomberg Businessweek
#           </a>
#          </li>
#          <li>
#           <a href="/tech">
#            Tech
#           </a>
#          </li>
#          <li>
#           <a href="/peninsula">
#            Península
#           </a>
#          </li>
#          <li>
#           <a href="https://www.nacion321.com">
#            Nacion 321
#           </a>
#          </li>
#         </ul>
#         <ul class="primary is-hidden-mobile">
#          <li>
#           <a href="/mercados">
#            Mercados
#           </a>
#          </li>
#          <li>
#           <a href="/economia">
#            Economía
#           </a>
#          </li>
#          <li>
#           <a href="/empresas">
#            Empresas
#           </a>
#          </li>
#          <li>
#           <a href="/bloomberg-businessweek">
#            Bloomberg Businessweek
#           </a>
#          </li>
#          <li>
#           <a href="/bloomberg">
#            Bloomberg
#           </a>
#          </li>
#          <li>
#           <a href="/mis-finanzas">
#            Mis Finanzas
#           </a>
#          </li>
#          <li>
#           <a href="/tlcan">
#            TLCAN
#           </a>
#          </li>
#         </ul>
#         <ul class="secondary is-hidden-mobile">
#          <li>
#           <a href="/financial-times">
#            Financial Times
#           </a>
#          </li>
#          <li>
#           <a href="/franquicias">
#            Franquicias
#           </a>
#          </li>
#          <li>
#           <a href="/pyme">
#            PyME
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="column is-3-desktop is-6-tablet is-hidden-mobile">
#         <ul class="secondary">
#          <!--li-->
#          <!--  a(href='/transicion') Transición-->
#          <li>
#           <a href="/nacional">
#            Nacional
#           </a>
#          </li>
#          <li>
#           <a href="/mundo">
#            Mundo
#           </a>
#          </li>
#          <li>
#           <a href="/bajio">
#            Bajío
#           </a>
#          </li>
#          <li>
#           <a href="/monterrey">
#            Monterrey
#           </a>
#          </li>
#          <li>
#           <a href="/encuestas">
#            Encuestas
#           </a>
#          </li>
#          <li>
#           <a href="/peninsula">
#            Península
#           </a>
#          </li>
#          <li class="is-nacion">
#           <a href="https://www.nacion321.com/" target="_blank">
#            <img src="/resources/images/nacion321.svg"/>
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="column is-3-desktop is-6-tablet is-hidden-mobile is-opinion">
#         <ul class="secondary">
#          <li>
#           <a href="/opinion">
#            Opinión
#           </a>
#          </li>
#          <li>
#           <a href="/opinion/enrique-quintana">
#            Enrique Quintana
#           </a>
#          </li>
#          <li>
#           <a href="/opinion/raymundo-riva-palacio">
#            Raymundo Riva Palacio
#           </a>
#          </li>
#          <li>
#           <a href="/opinion/pablo-hiriart">
#            Pablo Hiriart
#           </a>
#          </li>
#          <li>
#           <a href="/opinion/jonathan-ruiz">
#            Jonathan Ruiz
#           </a>
#          </li>
#          <li>
#           <a href="/opinion/salvador-camarena">
#            Salvador Camarena
#           </a>
#          </li>
#          <li>
#           <a href="/opinion/macario-schettino">
#            Macario Schettino
#           </a>
#          </li>
#          <li>
#           <a href="/opinion/javier-risco">
#            Javier Risco
#           </a>
#          </li>
#          <li>
#           <a href="/opinion/victor-piz">
#            Víctor Piz
#           </a>
#          </li>
#          <li>
#           <a href="/blogs">
#            Blogs
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="column is-3-desktop is-6-tablet is-hidden-mobile is-efbtv">
#         <ul class="secondary">
#          <li>
#           <a href="/tv">
#            <img src="/resources/images/logo-elfinanciero-bloombergtv-morado.svg"/>
#           </a>
#          </li>
#          <li>
#           <a href="/tv/al-cierre">
#            Al Cierre
#           </a>
#          </li>
#          <li>
#           <a href="/tv/la-nota-dura">
#            La Nota Dura
#           </a>
#          </li>
#          <li>
#           <a href="/tv/la-silla-roja">
#            La Silla Roja
#           </a>
#          </li>
#          <li>
#           <a href="/tv/en-ef-y-por-adela">
#            En EF y por Adela
#           </a>
#          </li>
#          <li>
#           <a href="/tv/bitacora-politica">
#            Bitácora política
#           </a>
#          </li>
#          <li>
#           <a href="/tv/mesa-central">
#            Mesa Central
#           </a>
#          </li>
#          <li>
#           <a href="/tv/ganadores-y-perdedores">
#            Ganadores y perdedores
#           </a>
#          </li>
#          <li>
#           <a href="/tv/al-sonar-la-campana">
#            Al sonar la campana
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="columns is-multiline is-menu-row is-hidden-touch">
#        <div class="column is-3">
#         <ul class="secondary">
#          <li>
#           <a href="/buena-vida">
#            Buena Vida
#           </a>
#          </li>
#          <li>
#           <a href="/culturas">
#            Culturas
#           </a>
#          </li>
#          <li>
#           <a href="/deportes">
#            Deportes
#           </a>
#          </li>
#          <li>
#           <a href="/reflector">
#            Reflector
#           </a>
#          </li>
#          <li>
#           <a href="/viajes">
#            Viajes
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="column is-3">
#         <ul class="secondary">
#          <li>
#           <a href="/tech">
#            Tech
#           </a>
#          </li>
#          <li>
#           <a href="/management">
#            Management
#           </a>
#          </li>
#          <li>
#           <a href="/emprendedores">
#            Emprendedores
#           </a>
#          </li>
#          <li>
#           <a href="/millonarios">
#            Millonarios
#           </a>
#          </li>
#          <li>
#           <a href="/rankings">
#            Rankings
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="column is-3">
#         <ul class="secondary">
#          <li>
#           <a href="/relojes">
#            Relojes
#           </a>
#          </li>
#          <li>
#           <a href="/ciencia">
#            Ciencia
#           </a>
#          </li>
#          <li>
#           <a href="/autos">
#            Autos
#           </a>
#          </li>
#          <li>
#           <a href="/sibarita">
#            Sibarita
#           </a>
#          </li>
#          <li>
#           <a href="/interactivos">
#            Interactivos
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="column is-3">
#         <ul class="secondary">
#          <li>
#           <a href="/mundo-empresa">
#            Mundo Empresa
#           </a>
#          </li>
#          <li>
#           <a href="/sponsor">
#            Sponsor
#           </a>
#          </li>
#          <li>
#           <a href="/suplementos">
#            Suplementos
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="columns is-multiline">
#        <div class="column is-hidden-mobile is-12-tablet is-6-desktop is-suscribe blue-row">
#         <ul>
#          <li>
#           <a>
#            SUSCRÍBETE A
#           </a>
#          </li>
#          <li>
#           <a href="https://suscripciones.elfinanciero.com.mx/elite/">
#            EL FINANCIERO
#           </a>
#          </li>
#          <li>
#           <a href="https://www.elfinanciero.com.mx/paper">
#            E-PAPER
#           </a>
#          </li>
#          <li>
#           <a href="https://elfinanciero.activehosted.com/f/1">
#            NEWSLETTER
#           </a>
#          </li>
#          <li>
#           <a href="https://suscripciones.elfinanciero.com.mx/elite/">
#            BUSINESSWEEK
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="column is-12-mobile is-6-tablet is-3-desktop is-app white-row">
#         <ul>
#          <li>
#           <a>
#            DESCARGAR APP
#           </a>
#          </li>
#          <li>
#           <a href="https://itunes.apple.com/mx/app/el-financiero/id668730716?mt=8">
#            <i class="fab fa-apple on-left">
#            </i>
#            iOS
#           </a>
#          </li>
#          <li>
#           <a href="https://play.google.com/store/apps/details?id=com.mx.grupolauman.elfinanciero">
#            <i class="fab fa-android on-left">
#            </i>
#            Android
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="column is-12-mobile is-6-tablet is-3-desktop is-networks white-row">
#         <ul>
#          <li>
#           <a>
#            REDES
#           </a>
#          </li>
#          <li>
#           <a href="https://www.facebook.com/ElFinancieroMx" target="_blank">
#            <i class="fab fa-facebook-square">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a href="https://twitter.com/ElFinanciero_Mx" target="_blank">
#            <i class="fab fa-twitter">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a href="https://www.linkedin.com/company/90169/" target="_blank">
#            <i class="fab fa-linkedin-in">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a href="https://www.instagram.com/elfinanciero_mx/" target="_blank">
#            <i class="fab fa-instagram">
#            </i>
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#      <script>
#       function PopupCenter(url, title, w, h) {
#   // Fixes dual-screen position                         Most browsers      Firefox
#   var dualScreenLeft = window.screenLeft != undefined ? window.screenLeft : window.screenX;
#   var dualScreenTop = window.screenTop != undefined ? window.screenTop : window.screenY;
#
#   var width = window.innerWidth ? window.innerWidth : document.documentElement.clientWidth ? document.documentElement.clientWidth : screen.width;
#   var height = window.innerHeight ? window.innerHeight : document.documentElement.clientHeight ? document.documentElement.clientHeight : screen.height;
#
#   var left = ((width / 2) - (w / 2)) + dualScreenLeft;
#   var top = ((height / 2) - (h / 2)) + dualScreenTop;
#   var newWindow = window.open(url, title, 'scrollbars=yes, width=' + w + ', height=' + h + ', top=' + top + ', left=' + left);
#
#   // Puts focus on the newWindow
#   if (window.focus) {
#       newWindow.focus();
#   }
# }
#      </script>
#     </div>
#    </div>
#   </div>
#   <script>
#    function PopupCenter(url, title, w, h) {
#   // Fixes dual-screen position                         Most browsers      Firefox
#   var dualScreenLeft = window.screenLeft != undefined ? window.screenLeft : window.screenX;
#   var dualScreenTop = window.screenTop != undefined ? window.screenTop : window.screenY;
#
#   var width = window.innerWidth ? window.innerWidth : document.documentElement.clientWidth ? document.documentElement.clientWidth : screen.width;
#   var height = window.innerHeight ? window.innerHeight : document.documentElement.clientHeight ? document.documentElement.clientHeight : screen.height;
#
#   var left = ((width / 2) - (w / 2)) + dualScreenLeft;
#   var top = ((height / 2) - (h / 2)) + dualScreenTop;
#   var newWindow = window.open(url, title, 'scrollbars=yes, width=' + w + ', height=' + h + ', top=' + top + ', left=' + left);
#
#   // Puts focus on the newWindow
#   if (window.focus) {
#       newWindow.focus();
#   }
# }
# var env = "https://api.elfinanciero.com.mx/public"
#   $.ajax({
#     url: env+'/notas/breaking-news',
#     method: 'GET',
#     dataType: 'JSON',
#   }).done(function(response){
#     var data = response.data[0]
#     var slug = '/'+data.slug;
#     var facebookSlug = 'https://www.facebook.com/sharer/sharer.php?u=https://elfinanciero.com.mx' + slug;
#     var twitterSlug = 'https://twitter.com/intent/tweet?url=https://elfinanciero.com.mx' + slug + '&text=' + encodeURIComponent(data.title) + '&via=ElFinanciero_Mx';
#     var whatsSlug = 'whatsapp://send?text=https://elfinanciero.com.mx' + slug;
#     $(".header-breaking-news").addClass("there-is-breaking");
#     $(".header-breaking-news .column.is-11 .slug").html(data.title);
#     $("a[href='breaking']").attr('href', slug);
#     $("a[href='twitter']").attr('href', twitterSlug);
#     $("a[href='facebook']").attr('href', facebookSlug);
#     $("a[href='whatsapp']").attr('href', whatsSlug);
#   }).fail(function(response){
#     console.log();
#   });
#   </script>
#   <div class="header-breaking-news">
#    <div class="container">
#     <div class="columns is-multiline is-mobile">
#      <div class="column is-11">
#       <a class="slug" href="breaking">
#        Breaking News
#       </a>
#       <a class="break-twitter social" href="twitter" target="_blank">
#        <i class="fab fa-twitter">
#        </i>
#       </a>
#       <a class="break-facebook social" href="facebook" target="_blank">
#        <i class="fab fa-facebook-square">
#        </i>
#       </a>
#       <a class="break-whatsapp social is-hidden-tablet" href="whatsapp" target="_blank">
#        <i class="fab fa-whatsapp-square">
#        </i>
#       </a>
#      </div>
#      <div class="column is-1 has-text-right">
#       <a class="close-bn">
#        <i class="fas fa-times">
#        </i>
#       </a>
#       <script>
#        $(".close-bn").click(function() {
# $(".header-breaking-news").slideUp(200);
# });
#       </script>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script>
#    $("#full-menu-trigger").ready(function() {
#   var timer;
#   var mTrigger = [$("#full-menu-trigger"), $("#full-menu")];
#   $.each(mTrigger, function() {
#     $(this).mouseleave(function() {
#       timer = setTimeout(function() {
#         $("#full-menu").slideUp(200);
#       }, 200);
#     });
#     $(this).mouseenter(function() {
#       clearInterval(timer);
#       $("#full-menu").slideDown(200);
#     });
#   });
# });
#
# $("#touch-menu-trigger").click(function() {
#   $("#full-menu").slideToggle(200, function() {
#     if($(".top-search").css("display") == "block") {
#       $(".top-search").slideUp(200);
#     }
#   });
# });
#
# $(".search-button").click(function() {
#   $(".top-search").slideToggle(200, function() {
#     if($(".top-search").css("display") == "block") {
#       $("#full-menu").slideUp(200);
#       $(".top-search").find("input").focus();
#     }
#   });
# });
#
# $(".top-search").find(".close-search").click(function() {
#   $(".top-search").slideUp(200);
# });
#
#
# var hasStickyTopHeader = true;
#   </script>
#   <style>
#    /* add colors as needed */
# .section-name.section__color-default {
#   color: #111;
# }
# .section__color-default.active {
#   background-color: #039;
# }
# .section__color-default.active .head {
#   color: #fff !important;
# }
# .section__color-default.active .bullet {
#   color: #d1eaff !important;
# }
#
# .section-name.section__color-softnews {
#   color: #742b63;
# }
# .section__color-softnews.active {
#   background-color: #742b63;
# }
# .section__color-softnews.active .head {
#   color: #fff !important;
# }
# .section__color-softnews.active .bullet {
#   color: #ffe8fa !important;
# }
#
# .section-name.section__color-bbw {
#   color: #111;
# }
# .section__color-bbw.active {
#   background-color: #111;
# }
# .section__color-bbw.active .head {
#   color: #fff !important;
# }
# .section__color-bbw.active .bullet {
#   color: #b6b6b6 !important;
# }
#
# .section-name.section__color-ft {
#   color: #ffecdb;
# }
# .section__color-ft.active {
#   background-color: #ffecdb;
# }
# .section__color-ft.active .head {
#   color: #33302e !important;
# }
# .section__color-ft.active .bullet {
#   color: #666 !important;
# }
#
# .section-name.section__color-bloomberg {
#   color: #1e00af;
# }
# .section__color-bloomberg.active {
#   background-color: #1e00af;
# }
# .section__color-bloomberg.active .head {
#   color: #fff !important;
# }
# .section__color-bloomberg.active .bullet {
#   color: #c5b9ff !important;
# }
#
# .section-name.section__color-nyt {
#   color: #231f20;
# }
# .section__color-nyt.active {
#   background-color: #231f20;
# }
# .section__color-nyt.active .head {
#   color: #fff !important;
# }
# .section__color-nyt.active .bullet {
#   color: #d5d5d5 !important;
# }
# .section-cover .sidebar {
#   z-index: 1;
# }
#
# .fold.is-golden-zone-html {
#   padding-top: 0;
#   padding-bottom: 0;
#   overflow: hidden;
# }
# @media screen and (min-width: 1008px) {
#   .section-logo {
#     max-width: 60%;
#   }
# }
# @media screen and (max-width: 767px) {
#   .section-logo {
#     padding-bottom: 1.75rem;
#   }
# }
#   </style>
#   <style>
#    /***** Golden Zone HTML *****/
#
# .fold.is-golden-zone-html {
# }
#
# .fold.is-golden-zone-html .container {
#   margin-top: 0 !important;
#   margin-bottom: 0 !important;
# }
#   </style>
#   <!-- Apertura a todo lo ancho de Video (si existe)-->
#   <div class="right_main_column">
#    <div class="content">
#     <div class="content-columns">
#     </div>
#    </div>
#   </div>
#   <div class="section section-cover">
#    <div class="container">
#     <div class="columns section-cover-head">
#      <div class="column is-12-mobile is-7-tablet is-8-desktop">
#       <!--If title-->
#       <h1 class="section-name section__color-default">
#        Economía
#       </h1>
#      </div>
#      <div class="column is-hidden-touch is-4-desktop has-text-right">
#       <!-- - Tag APN Superbanner-->
#       <div class="ad-slot" data-adtype="home.oreja" id="home_oreja">
#       </div>
#      </div>
#     </div>
#    </div>
#    <!--Prime zone One Note (si existe)-->
#    <div class="container">
#     <div class="columns">
#      <div class="column">
#       <div class="columns is-multiline is-mobile top-3">
#        <div class="column column-box is-12-mobile is-4-tablet">
#         <a href="/economia/moodys-alerta-sobre-plan-del-gobierno-de-amlo-para-refinerias-de-pemex">
#          <div class="top-box section__color-default">
#           <figure class="is-16-9">
#            <img src="/uploads/2018/12/21/c55430fdfd1545404498_standard_desktop_large.jpeg"/>
#           </figure>
#           <h2 class="head">
#            Moody's alerta sobre plan del Gobierno de AMLO para refinerías de Pemex
#           </h2>
#           <p class="bullet">
#            La agencia subrayó que la administración federal debe buscar invertir más en la producción de hidrocarburos para evitar que el balance energético del país esté en desventaja frente a EU.
#           </p>
#          </div>
#         </a>
#        </div>
#        <div class="column column-box is-12-mobile is-4-tablet">
#         <a href="/economia/y-a-todo-esto-cuanto-va-a-crecer-la-economia-de-mexico-en-2019">
#          <div class="top-box section__color-default">
#           <figure class="is-16-9">
#            <img src="/uploads/2019/04/11/2119b8d43e1555009935_standard_desktop_large.jpeg"/>
#           </figure>
#           <h2 class="head">
#            Y a todo esto, ¿cuánto va a crecer la economía de México en 2019?
#           </h2>
#           <p class="bullet">
#            La economía mexicana ha dado señales de desaceleración, por lo que diversos organismos han recortado su pronóstico de crecimiento para este año.
#           </p>
#          </div>
#         </a>
#        </div>
#        <div class="column column-box is-12-mobile is-4-tablet">
#         <a href="/economia/harvard-le-entra-al-negocio-de-criptomonedas">
#          <div class="top-box section__color-default">
#           <figure class="is-16-9">
#            <img src="/uploads/2019/04/11/191c62d3421555023997_standard_desktop_large.jpeg"/>
#           </figure>
#           <h2 class="head">
#            Harvard le 'entra' al negocio de criptomonedas
#           </h2>
#           <p class="bullet">
#            El fondo de la universidad está respaldando a Blockstack, una firma dedicada a los activos digitales.
#           </p>
#          </div>
#         </a>
#        </div>
#       </div>
#       <div class="columns is-hidden-desktop">
#        <div class="column">
#         <div class="ad-holder for300w">
#          <script>
#           EF.ads.create('home', 'sidebar', 'mobile');
#          </script>
#         </div>
#        </div>
#       </div>
#       <div class="columns is-hidden-tablet">
#        <div class="column">
#         <div class="most-read">
#          <div class="most-read">
#           <p class="title">
#            Más populares
#           </p>
#           <ol>
#            <li>
#             <a href="/economia/amlo-propone-crear-gasolineras-del-gobierno-si-continuan-abusos-en-precios-de-los-combustibles">
#              <div class="image is-hidden-mobile">
#               <img alt="AMLO propone crear gasolineras del Gobierno si continúan 'abusos' en precios de los combustibles " src="/uploads/2019/04/09/135593dd9b1554814321_smartphone.png" title="AMLO propone crear gasolineras del Gobierno si continúan 'abusos' en precios de los combustibles "/>
#              </div>
#              <p>
#               AMLO propone crear gasolineras del Gobierno si continúan 'abusos' en precios de los combustibles
#              </p>
#             </a>
#            </li>
#            <li>
#             <a href="/economia/imco-propone-cancelar-refineria-de-dos-bocas-inversion-solo-tiene-2-de-probabilidad-de-exito">
#              <div class="image is-hidden-mobile">
#               <img alt="IMCO propone cancelar refinería de Dos Bocas; inversión solo tiene 2% de probabilidad de éxito" src="/uploads/2019/04/09/2ef3e50fd71554825320_smartphone.jpeg" title="IMCO propone cancelar refinería de Dos Bocas; inversión solo tiene 2% de probabilidad de éxito"/>
#              </div>
#              <p>
#               IMCO propone cancelar refinería de Dos Bocas; inversión solo tiene 2% de probabilidad de éxito
#              </p>
#             </a>
#            </li>
#            <li>
#             <a href="/economia/persisten-riesgos-que-pueden-afectar-capacidad-de-crecimiento-banxico">
#              <div class="image is-hidden-mobile">
#               <img alt="Esta es la 'receta' que le da el Banxico al Gobierno de López Obrador para la economía" src="/uploads/2019/04/10/398475c83b1554911686_smartphone.jpeg" title="Esta es la 'receta' que le da el Banxico al Gobierno de López Obrador para la economía"/>
#              </div>
#              <p>
#               Esta es la 'receta' que le da el Banxico al Gobierno de López Obrador para la economía
#              </p>
#             </a>
#            </li>
#            <li>
#             <a href="/economia/5-indicadores-que-apuntan-a-una-menor-desaceleracion-en-mexico">
#              <div class="image is-hidden-mobile">
#               <img alt="5 indicadores que apuntan a una menor desaceleración en México" src="/uploads/2019/04/09/a992995ef41554865596_smartphone.png" title="5 indicadores que apuntan a una menor desaceleración en México"/>
#              </div>
#              <p>
#               5 indicadores que apuntan a una menor desaceleración en México
#              </p>
#             </a>
#            </li>
#            <li>
#             <a href="/economia/cofece-coincide-con-amlo-los-margenes-de-ganancia-de-gasolineros-han-aumentado">
#              <div class="image is-hidden-mobile">
#               <img alt="Cofece coincide con AMLO: los márgenes de ganancia de gasolineros han aumentado" src="/uploads/2019/04/10/fecbfa88f31554914294_smartphone.jpeg" title="Cofece coincide con AMLO: los márgenes de ganancia de gasolineros han aumentado"/>
#              </div>
#              <p>
#               Cofece coincide con AMLO: los márgenes de ganancia de gasolineros han aumentado
#              </p>
#             </a>
#            </li>
#            <li>
#             <a href="/economia/mexico-tendra-superavit-fiscal-todo-el-sexenio-estima-el-fmi">
#              <div class="image is-hidden-mobile">
#               <img alt="México tendrá superávit fiscal todo el sexenio, estima el FMI
# " src="/uploads/2019/02/22/147540e1291550865473_smartphone.jpeg" title="México tendrá superávit fiscal todo el sexenio, estima el FMI
# "/>
#              </div>
#              <p>
#               México tendrá superávit fiscal todo el sexenio, estima el FMI
#              </p>
#             </a>
#            </li>
#            <li>
#             <a href="/economia/fmi-recorta-pronostico-de-crecimiento-para-mexico-en-2019-y-2020">
#              <div class="image is-hidden-mobile">
#               <img alt="FMI reduce sus estimados para México por falta de certidumbre
# " src="/uploads/2019/04/10/c56030557e1554880259_smartphone.png" title="FMI reduce sus estimados para México por falta de certidumbre
# "/>
#              </div>
#              <p>
#               FMI reduce sus estimados para México por falta de certidumbre
#              </p>
#             </a>
#            </li>
#            <li>
#             <a href="/economia/tu-declaracion-anual-te-tomara-solo-2-minutos-como-dice-el-sat-no-y-contadores-te-explican-por-que">
#              <div class="image is-hidden-mobile">
#               <img alt="¿Tu declaración anual te tomará solo 2 minutos como dice el SAT? No... y contadores te explican por qué" src="/uploads/2019/04/10/1a77befc3b1554932532_smartphone.jpeg" title="¿Tu declaración anual te tomará solo 2 minutos como dice el SAT? No... y contadores te explican por qué"/>
#              </div>
#              <p>
#               ¿Tu declaración anual te tomará solo 2 minutos como dice el SAT? No... y contadores te explican por qué
#              </p>
#             </a>
#            </li>
#            <li>
#             <a href="/economia/glencore-gana-contrato-por-520-mdd-para-venderle-carbon-a-la-cfe">
#              <div class="image is-hidden-mobile">
#               <img alt="Glencore gana contrato por 520 mdd para venderle carbón a la CFE" src="/uploads/2019/04/09/8038da89e41554867127_smartphone.png" title="Glencore gana contrato por 520 mdd para venderle carbón a la CFE"/>
#              </div>
#              <p>
#               Glencore gana contrato por 520 mdd para venderle carbón a la CFE
#              </p>
#             </a>
#            </li>
#            <li>
#             <a href="/economia/gobernador-de-tabasco-refuta-al-imco-y-defiende-construccion-de-refineria-en-dos-bocas">
#              <div class="image is-hidden-mobile">
#               <img alt="Gobernador de Tabasco refuta al IMCO y defiende construcción de refinería en Dos Bocas" src="/uploads/2019/04/10/75df6360981554927922_smartphone.jpeg" title="Gobernador de Tabasco refuta al IMCO y defiende construcción de refinería en Dos Bocas"/>
#              </div>
#              <p>
#               Gobernador de Tabasco refuta al IMCO y defiende construcción de refinería en Dos Bocas
#              </p>
#             </a>
#            </li>
#           </ol>
#           <p>
#           </p>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="columns">
#        <div class="column">
#         <div class="feed">
#          <a href="/economia/jpmorgan-coloca-deuda-de-venezuela-en-indice-de-vigilancia">
#           <div class="columns is-mobile item">
#            <div class="column is-3">
#             <img src="/uploads/2019/04/11/6f16f5fc2c1555028992_smartphone.jpeg"/>
#            </div>
#            <div class="column no-padding-left">
#             <p class="date-time is-hidden-mobile">
#              11/4/2019
#             </p>
#             <p class="head">
#              JPMorgan coloca deuda de Venezuela en índice de 'vigilancia'
#             </p>
#            </div>
#           </div>
#          </a>
#          <a href="/peninsula/inversion-publica-factor-para-combatir-pobreza-e-impulsar-economia-urzua">
#           <div class="columns is-mobile item">
#            <div class="column is-3">
#             <img src="/uploads/2019/04/11/4d8556695c1555006083_smartphone.jpeg"/>
#            </div>
#            <div class="column no-padding-left">
#             <p class="date-time is-hidden-mobile">
#              11/4/2019
#             </p>
#             <p class="head">
#              Los pronósticos de crecimiento económico son adivinanzas: Urzúa
#             </p>
#            </div>
#           </div>
#          </a>
#          <a href="/economia/coparmex-pide-no-precipitarse-con-la-reforma-laboral">
#           <div class="columns is-mobile item">
#            <div class="column is-3">
#             <img src="/uploads/2019/04/11/1fffeb21921555018564_smartphone.jpeg"/>
#            </div>
#            <div class="column no-padding-left">
#             <p class="date-time is-hidden-mobile">
#              11/4/2019
#             </p>
#             <p class="head">
#              Coparmex pide no precipitarse con la reforma laboral
#             </p>
#            </div>
#           </div>
#          </a>
#          <a href="/economia/quieres-ganar-54-mil-pesos-en-canada-como-programador-hay-25-vacantes">
#           <div class="columns is-mobile item">
#            <div class="column is-3">
# ...
#            </p>
#           </a>
#          </li>
#          <li>
#           <a href="/economia/imco-propone-cancelar-refineria-de-dos-bocas-inversion-solo-tiene-2-de-probabilidad-de-exito">
#            <div class="image is-hidden-mobile">
#             <img alt="IMCO propone cancelar refinería de Dos Bocas; inversión solo tiene 2% de probabilidad de éxito" src="/uploads/2019/04/09/2ef3e50fd71554825320_smartphone.jpeg" title="IMCO propone cancelar refinería de Dos Bocas; inversión solo tiene 2% de probabilidad de éxito"/>
#            </div>
#            <p>
#             IMCO propone cancelar refinería de Dos Bocas; inversión solo tiene 2% de probabilidad de éxito
#            </p>
#           </a>
#          </li>
#          <li>
#           <a href="/economia/persisten-riesgos-que-pueden-afectar-capacidad-de-crecimiento-banxico">
#            <div class="image is-hidden-mobile">
#             <img alt="Esta es la 'receta' que le da el Banxico al Gobierno de López Obrador para la economía" src="/uploads/2019/04/10/398475c83b1554911686_smartphone.jpeg" title="Esta es la 'receta' que le da el Banxico al Gobierno de López Obrador para la economía"/>
#            </div>
#            <p>
#             Esta es la 'receta' que le da el Banxico al Gobierno de López Obrador para la economía
#            </p>
#           </a>
#          </li>
#          <li>
#           <a href="/economia/5-indicadores-que-apuntan-a-una-menor-desaceleracion-en-mexico">
#            <div class="image is-hidden-mobile">
#             <img alt="5 indicadores que apuntan a una menor desaceleración en México" src="/uploads/2019/04/09/a992995ef41554865596_smartphone.png" title="5 indicadores que apuntan a una menor desaceleración en México"/>
#            </div>
#            <p>
#             5 indicadores que apuntan a una menor desaceleración en México
#            </p>
#           </a>
#          </li>
#          <li>
#           <a href="/economia/cofece-coincide-con-amlo-los-margenes-de-ganancia-de-gasolineros-han-aumentado">
#            <div class="image is-hidden-mobile">
#             <img alt="Cofece coincide con AMLO: los márgenes de ganancia de gasolineros han aumentado" src="/uploads/2019/04/10/fecbfa88f31554914294_smartphone.jpeg" title="Cofece coincide con AMLO: los márgenes de ganancia de gasolineros han aumentado"/>
#            </div>
#            <p>
#             Cofece coincide con AMLO: los márgenes de ganancia de gasolineros han aumentado
#            </p>
#           </a>
#          </li>
#          <li>
#           <a href="/economia/mexico-tendra-superavit-fiscal-todo-el-sexenio-estima-el-fmi">
#            <div class="image is-hidden-mobile">
#             <img alt="México tendrá superávit fiscal todo el sexenio, estima el FMI
# " src="/uploads/2019/02/22/147540e1291550865473_smartphone.jpeg" title="México tendrá superávit fiscal todo el sexenio, estima el FMI
# "/>
#            </div>
#            <p>
#             México tendrá superávit fiscal todo el sexenio, estima el FMI
#            </p>
#           </a>
#          </li>
#          <li>
#           <a href="/economia/fmi-recorta-pronostico-de-crecimiento-para-mexico-en-2019-y-2020">
#            <div class="image is-hidden-mobile">
#             <img alt="FMI reduce sus estimados para México por falta de certidumbre
# " src="/uploads/2019/04/10/c56030557e1554880259_smartphone.png" title="FMI reduce sus estimados para México por falta de certidumbre
# "/>
#            </div>
#            <p>
#             FMI reduce sus estimados para México por falta de certidumbre
#            </p>
#           </a>
#          </li>
#          <li>
#           <a href="/economia/tu-declaracion-anual-te-tomara-solo-2-minutos-como-dice-el-sat-no-y-contadores-te-explican-por-que">
#            <div class="image is-hidden-mobile">
#             <img alt="¿Tu declaración anual te tomará solo 2 minutos como dice el SAT? No... y contadores te explican por qué" src="/uploads/2019/04/10/1a77befc3b1554932532_smartphone.jpeg" title="¿Tu declaración anual te tomará solo 2 minutos como dice el SAT? No... y contadores te explican por qué"/>
#            </div>
#            <p>
#             ¿Tu declaración anual te tomará solo 2 minutos como dice el SAT? No... y contadores te explican por qué
#            </p>
#           </a>
#          </li>
#          <li>
#           <a href="/economia/glencore-gana-contrato-por-520-mdd-para-venderle-carbon-a-la-cfe">
#            <div class="image is-hidden-mobile">
#             <img alt="Glencore gana contrato por 520 mdd para venderle carbón a la CFE" src="/uploads/2019/04/09/8038da89e41554867127_smartphone.png" title="Glencore gana contrato por 520 mdd para venderle carbón a la CFE"/>
#            </div>
#            <p>
#             Glencore gana contrato por 520 mdd para venderle carbón a la CFE
#            </p>
#           </a>
#          </li>
#          <li>
#           <a href="/economia/gobernador-de-tabasco-refuta-al-imco-y-defiende-construccion-de-refineria-en-dos-bocas">
#            <div class="image is-hidden-mobile">
#             <img alt="Gobernador de Tabasco refuta al IMCO y defiende construcción de refinería en Dos Bocas" src="/uploads/2019/04/10/75df6360981554927922_smartphone.jpeg" title="Gobernador de Tabasco refuta al IMCO y defiende construcción de refinería en Dos Bocas"/>
#            </div>
#            <p>
#             Gobernador de Tabasco refuta al IMCO y defiende construcción de refinería en Dos Bocas
#            </p>
#           </a>
#          </li>
#         </ol>
#         <p>
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script>
#    $(window).bind("scroll", function() {
#   var viewportWidth = $(window).width();
#   if(viewportWidth >= 768) {
#     $(".most-read").find("li").each(function() {
#       var li = $(this);
#       var index = li.index();
#       var timer;
#       li.mouseenter(function() {
#         timer = setTimeout(function() {
#           li.siblings().find(".image").slideUp(300);
#           li.find(".image").slideDown(300);
#         }, 300);
#       });
#       li.mouseleave(function() {
#         clearInterval(timer);
#       });
#     });
#   }
# }).scroll();
#
# $(".top-box").mouseenter(function() {
#   $(this).addClass("active");
#   $(".top-box").not(this).removeClass("active");
# });
#
# $("document").ready(function(){
#   var currentPage = 1;
#   $('.load-more').click(function(){
#     //- ComScore Tag + txt
#     self.COMSCORE && COMSCORE.beacon({
#       'c1': '2',
#       'c2': '10181342'
#     });
#     $.get('/comscore_view.txt')
#     //- End ComScore
#     currentPage++;
#     $('.loadingWrapper').toggleClass('active');
#     $.ajax({
#       url : 'https://api.elfinanciero.com.mx/public\/search\/typed\/?_format=json&json={"search":"*","categoriesslug":"'+'economia'+'"}&type=page',
#       method : "GET",
#       data : {
#         page : currentPage,
#         size : 10
#       },
#       dataType : 'json'
#     }).done(function(response){
#       $('.loadingWrapper').toggleClass('active');
#       function insertImageSuffix (_src, _suffix) {
#         if (!_src) { return ''; }
#         var srcReturn = _src.slice(0, _src.lastIndexOf('.')) + _suffix + _src.slice(_src.lastIndexOf('.'));
#         return srcReturn;
#       };
#       var content = '';
#       if(response.data && response.data[1]){
#         var coverIds = '628339,628313,628362,628375,628305,628343,628320,628326,628325,628312'.split(',');
#         for(var i = 0; i<response.data[1].length; i++){
#           var item = response.data[1][i];
#           var date = new Date(item._source.publishedAt);
#           var yearf = date.getFullYear();
#           var month = date.getMonth()+1;
#           var thisPrime = $('.sectionFold.is-prime').find('div a:first').attr('href');
#           month = month < 10 ? '0' + month : month;
#           var day = date.getDate();
#           day = day < 10 ? '0' + day : day;
#           if(!coverIds.find(function(i){return Number(i) === Number(item._source.id)})) {
#             content += '<a href="/'+item._source.slug+'">'+
#               '<div class="columns is-mobile item">'+
#               ' <div class="column is-3"><img src="'+insertImageSuffix(item._source.mainImage, '_smartphone')+'"></div>'+
#               '  <div class="column no-padding-left">'+
#               '   <p class="date-time is-hidden-mobile">'+ day + '/' + month + '/' + yearf +'</p>'+
#               '   <p class="head">'+item._source.title+
#               '   </p>'+
#               '  </div>'+
#               '</div>'+
#             '</a>';
#           }
#         }
#       }
#       if(response.data[1].length < 10){
#         $('.load-more').hide();
#       }
#       $('.feed').append(content);
#     });
#   })
# })
#   </script>
#   <script async="true" class="teads" src="//a.teads.tv/page/59303/tag" type="text/javascript">
#   </script>
#   <script language="JavaScript1.3" src="https://sb.scorecardresearch.com/c2/10181342/ct.js" type="text/javascript">
#   </script>
#   <div id="footer">
#    <div class="container">
#     <div class="columns is-multiline is-mobile">
#      <div class="column is-hidden-touch is-2-desktop logo">
#       <a href="https://www.elfinanciero.com.mx">
#        <picture>
#         <source srcset="/resources/images/img_menu/svg/logo_mobile.svg"/>
#         <img src="/resources/images/img_menu/logo_mobile.png"/>
#        </picture>
#       </a>
#      </div>
#      <div class="column is-12-touch is-10-desktop menu">
#       <ul>
#        <li>
#         <a href="/quienes-somos">
#          ¿Quiénes somos?
#         </a>
#        </li>
#        <li>
#         <a href="/directorio">
#          Directorio
#         </a>
#        </li>
#        <li>
#         <a href="https://suscripciones.elfinanciero.com.mx/">
#          Suscripciones
#         </a>
#        </li>
#        <li>
#         <a href="/aviso-de-privacidad">
#          Aviso de Privacidad
#         </a>
#        </li>
#        <li>
#         <a href="mailto:inteligenciacomercial@elfinanciero.com.mx">
#          Anúnciate con Nosotros
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="columns is-multiline is-mobile">
#      <div class="column is-12-touch is-6-desktop copy">
#       <p>
#        2018 © Copyright, Grupo Multimedia Lauman, SAPI de CV
#       </p>
#      </div>
#      <div class="column is-12-touch is-6-desktop thrd-logos">
#       <img class="comscore" src="/resources/images/logos-com.svg"/>
#       <a href="https://www.elfinanciero.com.mx/rss/" target="_blank">
#        <img class="rss" src="/resources/images/logos-rss.svg"/>
#       </a>
#      </div>
#      <hr/>
#      <div class="column is-12-touch is-12-desktop copylegal">
#       <p>
#        La información, opinión y análisis contenidos en esta publicación son responsabilidad de los autores, salvo error de apreciación de su parte.
#       </p>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div id="fb-root">
#   </div>
#   <!-- jQuery-->
#   <script src="/resources/js/iframeResizer.min.js">
#   </script>
#   <script src="/resources/plugins/dropcap/dropcap.min.js">
#   </script>
#   <!-- UIKit-->
#   <script src="/resources/plugins/uikit/js/uikit.min.js">
#   </script>
#   <script src="/resources/plugins/uikit/js/components/sticky.js">
#   </script>
#   <script src="/resources/plugins/uikit/js/components/slider.js">
#   </script>
#   <script src="/resources/plugins/uikit/js/components/slideshow.js">
#   </script>
#   <script src="/resources/plugins/uikit/js/components/parallax.min.js">
#   </script>
#   <script src="/resources/plugins/uikit/js/components/slideset.min.js">
#   </script>
#   <script src="/resources/share/twitter/js/html2canvas.js">
#   </script>
#   <script src="/resources/share/twitter/js/jquery.plugin.html2canvas.js">
#   </script>
#   <script>
#    $(document).ready(function() {
#   // Check for true or false hasStickyTopHeader; in Note scroll it's false
#   if(hasStickyTopHeader) {
#     var headTime = 1000;
#     setTimeout(function() {
#       var stickyHeader = UIkit.sticky("#top-header");
#     }, headTime);
#   };
#   $(".adaptive-iframe").on('load', function () {
#     $(this).iFrameResize({
#       checkOrigin:false,
#       heightCalculationMethod: 'taggedElement'
#     });
#   });
#
#   // Drop Caps
#   var dropcap = $(".drop-cap");
#   $.each(dropcap, function(c) {
#     window.Dropcap.layout(this, 3);
#     this.style.fontFamily = "Geomanist";
#     this.style.fontWeight = "300";
#     this.style.paddingRight = "0.75rem";
#     this.style.letterSpacing = "-0.25rem";
#     dropcap.textContent = c;
#   });
#
#   $(document).find(".section.is-article").each(function() {
#     // Video main element to sidebar
#     if($(this).find(".page__main-element").find(".video-holder").length > 0) {
#       $(this).find(".sidebar__inner").prepend("<div class='side-video-holder is-16-9'></div>");
#       var videoHolder = $(this).find(".video-holder").first();
#       var sideVideoHolder = $(this).find(".side-video-holder");
#       var videoPlayer = videoHolder.find(".video-player").first();
#       var video = videoPlayer.find("video").first();
#       var isFS;
#       var state;
#       var whereAmI = "b";
#       var viewportWidth;
#       $(window).bind("scroll", function() {
#         viewportWidth = $(window).width();
#         if(viewportWidth >= 1008) {
#           if($(this).scrollTop() >= videoHolder.offset().top + (videoHolder.outerHeight() / 2) && document.webkitCurrentFullScreenElement == null) {
#             if(whereAmI != "s") {
#               sideVideoHolder.slideToggle();
#               state = video[0].paused;
#               videoPlayer.animate({
#                 top: -videoHolder.outerHeight() / 2,
#                 opacity: 0
#               }, function() {
#                 videoPlayer.prependTo(sideVideoHolder).animate({
#                 top: 0,
#                 opacity: 1
#                 }, 200, function() {
#                   if(!state) {
#                     video[0].play();
#                   }
#                 });
#               });
#               whereAmI = "s";
#             }
#           } else if($(this).scrollTop() < videoHolder.offset().top + (videoHolder.outerHeight() / 2) && document.webkitCurrentFullScreenElement == null){
#             if(whereAmI != "b") {
#               state = video[0].paused;
#               videoPlayer.animate({
#                 top: -sideVideoHolder.outerHeight() / 2,
#                 opacity: 0
#               }, function() {
#                 videoPlayer.prependTo(videoHolder).animate({
#                 top: 0,
#                 opacity: 1
#                 }, 200, function() {
#                   if(!state) {
#                     video[0].play();
#                   }
#                 });
#               });
#               sideVideoHolder.slideToggle();
#               whereAmI = "b";
#             }
#           }
#         }
#       });
#     }
#   });
# });
#   </script>
#   <script>
#    $('.search-field').on('keypress', function (e) {
#   var self=$(this);
#   if (e.which === 13) {
#     var value = self.val();
#     window.location = '/search/'+value;
#   }
# });
#   </script>
#   <!-- Twitter-->
#   <script async="" charset="utf-8" src="https://platform.twitter.com/widgets.js">
#   </script>
#   <script async="" src="/resources/js/dfp.js">
#   </script>
#   <script type="text/javascript">
#    // Set to false if opt-in required
# var trackByDefault = true;
# function acEnableTracking() {
# var expiration = new Date(new Date().getTime() + 1000 * 60 * 60 * 24 * 30);
# document.cookie = "ac_enable_tracking=1; expires= " + expiration + "; path=/";
# acTrackVisit();
# }
# function acTrackVisit() {
# var trackcmp_email = '';
# var trackcmp = document.createElement("script");
# trackcmp.async = true;
# trackcmp.type = 'text/javascript';
# trackcmp.src = 'https://trackcmp.net/visit?actid=799123891&e='+encodeURIComponent(trackcmp_email)+'&r='+encodeURIComponent(document.referrer)+'&u='+encodeURIComponent(window.location.href);
# var trackcmp_s = document.getElementsByTagName("script");
# if (trackcmp_s.length) {
# trackcmp_s[0].parentNode.appendChild(trackcmp);
# } else {
# var trackcmp_h = document.getElementsByTagName("head");
# trackcmp_h.length && trackcmp_h[0].appendChild(trackcmp);
# }
# }
# if (trackByDefault || /(^|; )ac_enable_tracking=([^;]+)/.test(document.cookie)) {
# acEnableTracking();
# }
#   </script>
#   <script>
#    console.log = function() {}
#   </script>
#   <script async="" defer="" src="/resources/js/note/datalayer.js">
#   </script>
#  </body>
# </html>

# %%
soup.title
# Out:
# <title>Economía</title>

# %%
soup.p
# Out:
# <p class="bullet">La agencia subrayó que la administración federal debe buscar invertir más en la producción de hidrocarburos para evitar que el balance energético del país esté en desventaja frente a EU. </p>

# %%
soup.a
# Out:
# <a class="close-search"><i class="fas fa-times"></i></a>

# %%
soup.find_all('b')
# Out:
# []

# %%
soup.find_all('a')
# Out:
# [<a class="close-search"><i class="fas fa-times"></i></a>,
#  <a href="https://www.facebook.com/ElFinancieroMx" target="_blank"><i class="fab fa-facebook-square"></i></a>,
#  <a href="https://twitter.com/ElFinanciero_Mx" target="_blank"><i class="fab fa-twitter"></i></a>,
#  <a href="https://www.linkedin.com/company/90169/" target="_blank"><i class="fab fa-linkedin-in"></i></a>,
#  <a href="https://www.instagram.com/elfinanciero_mx/" target="_blank"><i class="fab fa-instagram"></i></a>,
#  <a><i class="fas fa-search"></i></a>,
#  <a id="touch-menu-trigger"><img src="/resources/images/touch-menu-trigger.svg"/></a>,
#  <a href="/"><picture><source media="(max-width: 767px)" srcset="/resources/images/img_menu/svg/logo_mobile.svg"/><source media="(min-width: 768px)" srcset="/resources/images/img_menu/svg/logo.svg"/><img src="/resources/images/img_menu/png/logo.png"/></picture></a>,
#  <a href="/economia">ECONOMÍA</a>,
#  <a href="/mercados">MERCADOS</a>,
#  <a href="/opinion">OPINIÓN</a>,
#  <a href="/nacional">NACIONAL</a>,
#  <a href="/tv">TV</a>,
#  <a>· · ·</a>,
#  <a href="/economia">Economía</a>,
#  <a href="/empresas">Empresas</a>,
#  <a href="/mercados">Mercados</a>,
#  <a href="/nacional">Nacional</a>,
#  <a href="/opinion">Opinión</a>,
#  <a href="/tv">Televisión</a>,
#  <a href="/bloomberg-businessweek">Bloomberg Businessweek</a>,
#  <a href="/tech">Tech</a>,
#  <a href="/peninsula">Península</a>,
#  <a href="https://www.nacion321.com">Nacion 321</a>,
#  <a href="/mercados">Mercados</a>,
#  <a href="/economia">Economía</a>,
#  <a href="/empresas">Empresas</a>,
#  <a href="/bloomberg-businessweek">Bloomberg Businessweek</a>,
#  <a href="/bloomberg">Bloomberg</a>,
#  <a href="/mis-finanzas">Mis Finanzas</a>,
#  <a href="/tlcan">TLCAN</a>,
#  <a href="/financial-times">Financial Times</a>,
#  <a href="/franquicias">Franquicias</a>,
#  <a href="/pyme">PyME</a>,
#  <a href="/nacional">Nacional</a>,
#  <a href="/mundo">Mundo</a>,
#  <a href="/bajio">Bajío</a>,
#  <a href="/monterrey">Monterrey</a>,
#  <a href="/encuestas">Encuestas</a>,
#  <a href="/peninsula">Península </a>,
#  <a href="https://www.nacion321.com/" target="_blank"><img src="/resources/images/nacion321.svg"/></a>,
#  <a href="/opinion">Opinión</a>,
#  <a href="/opinion/enrique-quintana">Enrique Quintana</a>,
#  <a href="/opinion/raymundo-riva-palacio">Raymundo Riva Palacio</a>,
#  <a href="/opinion/pablo-hiriart">Pablo Hiriart</a>,
#  <a href="/opinion/jonathan-ruiz">Jonathan Ruiz</a>,
#  <a href="/opinion/salvador-camarena">Salvador Camarena</a>,
#  <a href="/opinion/macario-schettino">Macario Schettino</a>,
#  <a href="/opinion/javier-risco">Javier Risco</a>,
#  <a href="/opinion/victor-piz">Víctor Piz</a>,
#  <a href="/blogs">Blogs</a>,
#  <a href="/tv"><img src="/resources/images/logo-elfinanciero-bloombergtv-morado.svg"/></a>,
#  <a href="/tv/al-cierre">Al Cierre</a>,
#  <a href="/tv/la-nota-dura">La Nota Dura</a>,
#  <a href="/tv/la-silla-roja">La Silla Roja</a>,
#  <a href="/tv/en-ef-y-por-adela">En EF y por Adela</a>,
#  <a href="/tv/bitacora-politica">Bitácora política</a>,
#  <a href="/tv/mesa-central">Mesa Central</a>,
#  <a href="/tv/ganadores-y-perdedores">Ganadores y perdedores</a>,
#  <a href="/tv/al-sonar-la-campana">Al sonar la campana</a>,
#  <a href="/buena-vida">Buena Vida</a>,
#  <a href="/culturas">Culturas</a>,
#  <a href="/deportes">Deportes</a>,
#  <a href="/reflector">Reflector</a>,
#  <a href="/viajes">Viajes</a>,
#  <a href="/tech">Tech</a>,
#  <a href="/management">Management</a>,
#  <a href="/emprendedores">Emprendedores</a>,
#  <a href="/millonarios">Millonarios</a>,
#  <a href="/rankings">Rankings</a>,
#  <a href="/relojes">Relojes</a>,
#  <a href="/ciencia">Ciencia</a>,
#  <a href="/autos">Autos</a>,
#  <a href="/sibarita">Sibarita</a>,
#  <a href="/interactivos">Interactivos</a>,
#  <a href="/mundo-empresa">Mundo Empresa</a>,
#  <a href="/sponsor">Sponsor</a>,
#  <a href="/suplementos">Suplementos</a>,
#  <a>SUSCRÍBETE A</a>,
#  <a href="https://suscripciones.elfinanciero.com.mx/elite/">EL FINANCIERO</a>,
#  <a href="https://www.elfinanciero.com.mx/paper">E-PAPER</a>,
#  <a href="https://elfinanciero.activehosted.com/f/1">NEWSLETTER</a>,
#  <a href="https://suscripciones.elfinanciero.com.mx/elite/">BUSINESSWEEK</a>,
#  <a>DESCARGAR APP</a>,
#  <a href="https://itunes.apple.com/mx/app/el-financiero/id668730716?mt=8"><i class="fab fa-apple on-left"></i>iOS</a>,
#  <a href="https://play.google.com/store/apps/details?id=com.mx.grupolauman.elfinanciero"><i class="fab fa-android on-left"></i>Android</a>,
#  <a>REDES</a>,
#  <a href="https://www.facebook.com/ElFinancieroMx" target="_blank"><i class="fab fa-facebook-square"></i></a>,
#  <a href="https://twitter.com/ElFinanciero_Mx" target="_blank"><i class="fab fa-twitter"></i></a>,
#  <a href="https://www.linkedin.com/company/90169/" target="_blank"><i class="fab fa-linkedin-in"></i></a>,
#  <a href="https://www.instagram.com/elfinanciero_mx/" target="_blank"><i class="fab fa-instagram"></i></a>,
#  <a class="slug" href="breaking">Breaking News</a>,
#  <a class="break-twitter social" href="twitter" target="_blank"><i class="fab fa-twitter"></i></a>,
#  <a class="break-facebook social" href="facebook" target="_blank"><i class="fab fa-facebook-square"></i></a>,
#  <a class="break-whatsapp social is-hidden-tablet" href="whatsapp" target="_blank"><i class="fab fa-whatsapp-square"></i></a>,
#  <a class="close-bn"><i class="fas fa-times"></i></a>,
#  <a href="/economia/que-es-y-por-que-debe-preocuparme-el-regreso-de-la-tenencia"><div class="top-box section__color-default"><figure class="is-16-9"><img src="/uploads/2019/04/09/dca5672ff31554819689_standard_desktop_large.jpeg"/></figure><h2 class="head">¿Qué es la tenencia y por qué debería importarme?</h2><p class="bullet">Este impuesto, que ya no se cobra en algunos estados del país, cumplió 57 años en este 2019. Te contamos los detalles.</p></div></a>,
#  <a href="/economia/cuanto-ha-gastado-hacienda-para-costear-el-estimulo-fiscal-a-las-gasolinas"><div class="image is-hidden-mobile"><img alt="¿Cuánto ha gastado Hacienda para costear el estímulo fiscal a las gasolinas?" src="/uploads/2019/04/07/4f87658ef01554698163_smartphone.jpeg" title="¿Cuánto ha gastado Hacienda para costear el estímulo fiscal a las gasolinas?"/></div><p>¿Cuánto ha gastado Hacienda para costear el estímulo fiscal a las gasolinas?</p></a>,
#  <a href="/economia/con-amlo-mexico-cesa-la-compra-de-crudo-a-eu"><div class="image is-hidden-mobile"><img alt="Con AMLO, México cesa la compra de crudo a EU" src="/uploads/2019/02/27/ddbc86dc4b1551293773_smartphone.jpeg" title="Con AMLO, México cesa la compra de crudo a EU"/></div><p>Con AMLO, México cesa la compra de crudo a EU</p></a>,
#  <a href="/economia/gobierno-buscara-regular-outsourcing-no-desaparecerlo-luisa-maria-alcalde"><div class="image is-hidden-mobile"><img alt="Gobierno buscará regular 'outsourcing', no desaparecerlo: Luisa María Alcalde
#  " src="/uploads/2019/04/04/6f16f5fc2c1554431881_smartphone.jpeg" title="Gobierno buscará regular 'outsourcing', no desaparecerlo: Luisa María Alcalde
#  "/></div><p>Gobierno buscará regular 'outsourcing', no desaparecerlo: Luisa María Alcalde
#  </p></a>,
#  <a href="https://www.elfinanciero.com.mx"><picture><source srcset="/resources/images/img_menu/svg/logo_mobile.svg"/><img src="/resources/images/img_menu/logo_mobile.png"/></picture></a>,
#  <a href="/quienes-somos">¿Quiénes somos?</a>,
#  <a href="/directorio">Directorio</a>,
#  <a href="https://suscripciones.elfinanciero.com.mx/">Suscripciones</a>,
#  <a href="/aviso-de-privacidad">Aviso de Privacidad</a>,
#  <a href="mailto:inteligenciacomercial@elfinanciero.com.mx">Anúnciate con Nosotros</a>,
#  <a href="https://www.elfinanciero.com.mx/rss/" target="_blank"><img class="rss" src="/resources/images/logos-rss.svg"/></a>]

# %%
weblinks = soup.find_all('columns')
pagelinks = []
for link in weblinks[:]:    
      url = link.contents[0].find_all('a')[0]   
      pagelinks.append('http://www.elfinanciero.com.mx'+url.get('href'))
authorname = []
title = []
thearticle = []
for link in pagelinks:    
    # store the text for each article
    paragraphtext = []    
    # get url
    url = link
    # get page text
    page = requests.get(url)
    # parse with BFS
    soup = BeautifulSoup(page.text, 'html.parser')    
    # get author name, if there's a named author
    try:
        abody = soup.find(class_='d3284 africa').find('a')
        aname = abody.get_text() 
    except:
        aname = 'Anonymous'
    # get article title
    atitle = soup.find(class_="_21349 africa none _4ca8e")
    thetitle = atitle.get_text() 
    # get main article page
    articlebody = soup.find(class_='_61c55')
    # get text
    articletext = soup.find_all('p')[8:]
    # print text
    for paragraph in articletext[:-1]:

# %%
! pip install selenium
! pip install pandas
! pip install xlrd
! pip install openpyxl
from selenium import webdriver
import time

import pandas as pd
import numpy as np
from datetime import datetime

page = requests.get('https://qz.com/africa/latest')

soup = BeautifulSoup(page.content, 'html.parser')
weblinks = soup.find_all('article')

pagelinks = []
for link in weblinks[5:]:
    url = link.contents[0].find_all('a')[0]
    pagelinks.append('http://qz.com'+url.get('href'))

authorname = []
title = []
thearticle = []
for link in pagelinks:    
    # store the text for each article
    paragraphtext = []    
    # get url
    url = link
    # get page text
    page = requests.get(url)
    # parse with BFS
    soup = BeautifulSoup(page.text, 'html.parser')    
    # get author name, if there's a named author
    try:
        abody = soup.find(class_='d3284 africa').find('a')
        aname = abody.get_text() 
    except:
        aname = 'Anonymous'    

    # get article title
    atitle = soup.find(class_="_21349 africa none _4ca8e")
    thetitle = atitle.get_text() 
    # get main article page
    articlebody = soup.find(class_='_61c55')
    # get text
    articletext = soup.find_all('p')[8:]
    # print text
    for paragraph in articletext[:-1]:
        # get the text only
        text = paragraph.get_text()
        paragraphtext.append(text)        
    # combine all paragraphs into an article
    thearticle.append(paragraphtext)
    authorname.append(aname)
    title.append(thetitle)

# join paragraphs to re-create the article
myarticle = [' '.join(article) for article in thearticle]

# save article data to file
data = {'Title':title, 
        'Author':authorname, 
        'PageLink':pagelinks, 
        'Article':myarticle, 
        'Date':datetime.now()}

#oldnews = pd.read_excel('quartz\\news.xlsx')
news = pd.DataFrame(data=data)
cols = ['Title', 'Author', 'PageLink', 'Article', 'Date']
afronews = news[cols]

#afronews = oldnews.append(news)
#afronews.drop_duplicates(subset='Title', keep='last', inplace=True)
#afronews.reset_index(inplace=True)
#afronews.drop(labels='index', axis=1, inplace=True)

filename = 'quartz\\news.xlsx'
wks_name = 'Data'

writer = pd.ExcelWriter(filename)
afronews.to_excel(writer, wks_name, index=False)

writer.save()
# Out:
# Collecting selenium
#   Downloading https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl (904kB)
#     100% |████████████████████████████████| 911kB 738kB/s eta 0:00:01
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.6/site-packages (from selenium)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0
# You are using pip version 9.0.1, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: pandas in /opt/conda/lib/python3.6/site-packages
# Requirement already satisfied: python-dateutil>=2 in /opt/conda/lib/python3.6/site-packages (from pandas)
# Requirement already satisfied: pytz>=2011k in /opt/conda/lib/python3.6/site-packages (from pandas)
# Requirement already satisfied: numpy>=1.7.0 in /opt/conda/lib/python3.6/site-packages (from pandas)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.6/site-packages (from python-dateutil>=2->pandas)
# You are using pip version 9.0.1, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: xlrd in /opt/conda/lib/python3.6/site-packages
# You are using pip version 9.0.1, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting openpyxl
#   Downloading https://files.pythonhosted.org/packages/ba/06/b899c8867518df19e242d8cbc82d4ba210f5ffbeebb7704c695e687ab59c/openpyxl-2.6.2.tar.gz (173kB)
#     100% |████████████████████████████████| 174kB 2.7MB/s ta 0:00:01
# Collecting jdcal (from openpyxl)
#   Downloading https://files.pythonhosted.org/packages/a0/38/dcf83532480f25284f3ef13f8ed63e03c58a65c9d3ba2a6a894ed9497207/jdcal-1.4-py2.py3-none-any.whl
# Collecting et_xmlfile (from openpyxl)
#   Downloading https://files.pythonhosted.org/packages/22/28/a99c42aea746e18382ad9fb36f64c1c1f04216f41797f2f0fa567da11388/et_xmlfile-1.0.1.tar.gz
# Building wheels for collected packages: openpyxl, et-xmlfile
#   Running setup.py bdist_wheel for openpyxl ... done
#   Stored in directory: /home/jovyan/.cache/pip/wheels/82/cd/05/2e1db4b561fda743444f9573f2c5090a7b991200c92770dd7a
#   Running setup.py bdist_wheel for et-xmlfile ... done
#   Stored in directory: /home/jovyan/.cache/pip/wheels/2a/77/35/0da0965a057698121fc7d8c5a7a9955cdbfb3cc4e2423cad39
# Successfully built openpyxl et-xmlfile
# Installing collected packages: jdcal, et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.0.1 jdcal-1.4 openpyxl-2.6.2
# You are using pip version 9.0.1, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ced81eb99f44> in <module>()
#      10 from datetime import datetime
#      11
# ---> 12 page = requests.get('https://qz.com/africa/latest')
#      13
#      14 soup = BeautifulSoup(page.content, 'html.parser')
#
# NameError: name 'requests' is not defined
